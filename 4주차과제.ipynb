# %% [markdown]
# <a href="https://colab.research.google.com/github/pyunj/yun/blob/master/4%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4주차 과제
#
#    - 용어 정리
#    - 딥러닝 강의 클론 코딩
#    - 딥러닝 순전파 & 역전파 계산

# %% [markdown]
# ## 1. 용어 정리
#
# 다음 제시된 단어의 정의(설명)를 정리하여 작성하세요.
#   - 2문장 이상 작성해주세요.
#   - 주제(단어)와 크게 벗어나지만 않는다면 정답처리됩니다.
#   - 강의 뿐 아니라 기타 레퍼런스를 참고하여 작성하셔도 됩니다.(기타 레퍼런스를 참고하신 경우, 해당 레퍼런스를 정리하여 하단에 작성해주세요.)

# %% [markdown]
# __(예시)__
#
# ### 심층 신경망
#
# :입력층과 출력층 사이에 여러개의 은닉층들로 이뤄진 인공신경망이다. 심층 신경망은 일반적으로 인공신경망과 마찬가지로 복잡한 비선형 관계들을 모델링 할 수 있다. 심층신경망의 목적은 분류 및 수치예측을 하기 위함이고 이미지 트레이닝이나 문자인식과 같은 분야에 매우 유용하게 쓰이고 있다.

# %% [markdown]
# ### MCP 뉴런
# : AI를 설계하기 위해, 생물학적 뇌가 동작하는 방식을 이해하려는 시도로, 1943년 워랜 맥컬록과 월터 피츠는 간소화된 뇌의 뉴런 개념을 발표하였는데 이것이 MCP뉴런의 개념이다. 뉴런은 뇌의 신경세포와 연결되어 있으며, 화학적, 전기적 신호를 처리하고 전달하는데 관여한다. 이런 신경세포를 이진 출력을 내는 간단한 논리 회로로 표현하며 몇년 후에 프랭크 로젠 블렛은 MCP 뉴런 모델을 기반으로 퍼셉트론 학습 개념을 발표한다.
#
# ### 퍼셉트론
# : 자동으로 최적의 가중치를 학습하는 알고리즘을 제인하며 이 가중치는 뉴런의 출력 신호를 보낼지 말지 결정하기 위해 입력 특성에 곱하는 계수가 된다. 이런 퍼셉트론을 간단하게 표현하면 입력을 받아서 계산 후 출력을 반환하는 구조로 나타낼 수 있다. 퍼셉트론을 잘 이해하는 방법으로 AND, OR, XOR 연산 문제를 다르는 것이다.
#
# ### 역전파
# : 뉴런의 가치를 효율적으로 조정하기 위하여 거꾸로 무엇인가를 전파하는 방식이다.
# 신경망의 지도데이터와 출력값 사이의 오차로 가중치를 조정하는 것이며, 즉 출력값과 지도데이터 사이에 생기는 오차를 이용해 출력층에서 입력층쪽으로 가중치를 조정한다. 이러한 역전파는 경사하강법을 사용한다.
#   이렇게 역전파를 활용하게되면 신경망의 출력값부터 차례로 이전 노드값이 정해지게 되며, 이러한 역전파는 수열의 점화식처럼 오차를 전파하는 방법이다. 역전파는 때로는 역방향 미분이라고도 한다.
#
# ### 강화학습
# : 에이전트라는 존재가 환경과 상호작용하며, 이 환경에는 보상이라는 기준이 있어서 다양한 시행착오를 겪어가면서 보상을 최대화하는 방향으로 학습을 진행한다. 강화학습은 다양한 시행착오를 통해 학습이 가능하며, 비교적 명확한 보상을 설정할 수 있는 문제를 해결하는데 사용된다. 보상을 최대화하는 의사결정전략으로 순차적인 행동을 알아나가는 방법이다.
#
# ### 과적합
# : 결정트리 알고리즘을 사용하면 트리의 루트에서 시작해, 정보이득이란 값이 최대가 되는 특성으로 데이터를 나누는데 이러한 결정을 리프노드가 순수해질때까지 모든 자식 노드에 이 분할작업을 반복한다. 이와 같이 분할작업을 계속하다보면 깊은 트리가 만들어지게 되는데 이는 곧 과적합을 불러일을킨다. 그래서 일반적으로 트리의 최대 깊이를 제한하여 트리의 가지치기를 한다.
#
# ### 차원의 저주
# : 훈련 샘플 각가이 수천 심지어 수백만 개의 특성을 가지고 있을 때 훈련을 느리게 할 뿐 아니라, 최적의 솔루션을 찾기 어렵게 만드는 현상이다. 고차원으로 갈수록 전체 공간에서 데이터가 차기하는 공간이 매우 미비해진다. 새로운 샘플도 훈련 샘플과 멀리 떨어져 있을 가능성이 높다는 뜻으로 예측을 위해 훨씬 많은 작업을 하고, 저차원일 때보다 예측이 불안정해진다. 이런 차원의 저주를 해결하는 방법 중 하나는 훈련 샘풀의 밀도가 충분히 높아질 때까지 훈련 데이터의 크기를 키우는 것이다. 하지만 데이터가 무한정 있지 않기 때문에 이것은 힘들고 그래서 사용하는 방법 중 하나가 차원의 축소이다.
# http://blog.naver.com/PostView.nhn?blogId=qbxlvnf11&logNo=221323034856

# %% [markdown]
# ## 2. 딥러닝 강의 클론 코딩
#
# ####__퍼셉트론 구조 구현하기__
# 딥러닝 강의(__딥러닝 원리[1] 3:15 ~ 5:15부분__)를 보고 코드를 따라 치며 출력 결과를 만드세요.
#
# + 하나의 코드셀에 해당 코드를 한번에 다 적어 실행해주세요 (__그렇게 하지 않을 경우, 아래 이미지와 같은 출력값이 나오지 않을 수 있습니다__)
#
# + __주의!__ 실제로 코딩해서 출력해보면 강의에 나온 출력 결과와 다르게 나옵니다!!

# %%
import tensorflow as tf
tf.compat.v1.set_random_seed(2020)
x = 1
y = 0
w = tf.random.normal([1],0,1)

import math
def sigmoid(x):
  return 1/(1 + math.exp(-x))

output = sigmoid(x * w)
print(output)

for i in range(1000):
  output = sigmoid(x*w)
  error = y - output
  w = w + x * 0.1 * error

  if i % 100 == 99:
    print("함수 횟수:", i, "Error:",error, "예측결과:", output)
# Out:
# 0.47477188589261
# 함수 횟수: 99 Error: -0.10010598284299604 예측결과: 0.10010598284299604
# 함수 횟수: 199 Error: -0.05178399422833116 예측결과: 0.05178399422833116
# 함수 횟수: 299 Error: -0.034590451977903586 예측결과: 0.034590451977903586
# 함수 횟수: 399 Error: -0.02588962752851373 예측결과: 0.02588962752851373
# 함수 횟수: 499 Error: -0.020658699939863617 예측결과: 0.020658699939863617
# 함수 횟수: 599 Error: -0.017174253993457355 예측결과: 0.017174253993457355
# 함수 횟수: 699 Error: -0.014689506449480992 예측결과: 0.014689506449480992
# 함수 횟수: 799 Error: -0.012829497265431342 예측결과: 0.012829497265431342
# 함수 횟수: 899 Error: -0.011385568271837804 예측결과: 0.011385568271837804
# 함수 횟수: 999 Error: -0.010232493309882492 예측결과: 0.010232493309882492

# %% [markdown]
# ## 3. 딥러닝 순전파 & 역전파 계산
#
# 딥러닝 강의(__딥러닝 원리[2] 0:55 ~ 4:32부분__)에 나오는 순전파 & 역전파 계산에 대한 문제입니다.
#
# 해당 영상과 다음 이미지를 참고하여 다음 2가지 물음에 답하세요.
#
# (1) 학습률이 0.2일 경우 출력층의 노드값
#
# (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?

# %% [markdown]
# ![대체 텍스트](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Ff54dfd45-92ec-44ae-9616-6949d2484a45%2F_2020-06-10__5.22.03.png?table=block&id=ee05da89-3ceb-4ad9-a2d3-c9f68d24d1d9&width=3580&cache=v2)

# %% [markdown]
# ## (1) 학습률이 0.2일 경우 출력층의 노드값 :
# 1.6
# ## (2) 학습률이 0.1과 0.2 중 기대출력값이 지도데이터 "3"과 더 가까운 학습률은?:
# 0.1
