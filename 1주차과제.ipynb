# %% [markdown]
# <a href="https://colab.research.google.com/github/pyunj/yun/blob/master/1%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1강 요약정리

# %% [markdown]
# * 파이썬 자료형

# %%
mystr="hello"
myint=123
mylist=[True, False, True]

print(type(mystr), type(myint), type(mylist))
# Out:
# <class 'str'> <class 'int'> <class 'list'>

# %% [markdown]
# *   파이썬 연산자

# %% [markdown]
# ## 1주차 과제 (2020.05.27)

# %% [markdown]
# ### **이미지 인식**
# AI 이미지 인식에서 중요한 요소는 판별하고자 하는 __*이미지의 특징을 포착하고 추상화*__ 하는 것이다.

# %% [markdown]
# #### 이미지 인식의 사용사례
#
# 1. **스마트팩토리**
# 전자제품에 들어가는 유리기판 제조 생산 공장에서 부품 불량의 원인이 되는 기포와 먼지를 구별해 내는 것이 매우 중요하다. AI 이미지 분석 기술이 사람이 일일이 확인하는 것보다 오류 발생 확률을 현저히 낮추고 불량 판정률을 높일 수 이게 된다.
#
# 2. **보안검색대**
# 기존의 보완 검색대는 물건을 올리면 엑스레이로 촬영하여 사람이 판별해야 했다. 여기에 AI 이미지 분석 기술이 적용되면 보다 정확하게 촬영 이미지를 분석하여 반·출입 불허 물품을 자동으로 검색할 수 있게 된다.
#
# 3. **무인스토어**
# 셀프계산대에 AI 이미지 분석 시스템이 적용되어 구매자가 고른 제품을 계산대에 올리면 상품을 자동으로 인식하여 계산하는 것까지 가능하다.
#
# [네이버포스트](https://post.naver.com/viewer/postView.nhn?volumeNo=17875379&memberNo=39046504)

# %% [markdown]
# ### **언어**
# 한 커피브랜드에서 챗봇을 통해 고객이 쉽게 주문할 수 있도록 도움을 주고 있다.
# 고객이 "메뉴 추천해줘"라고 말하면 챗봇은 "최근 이용한 음료는 A,B,C입니다.
# 마음에 드시는 음료가 있나요?"라고 적절한 제안을 해준다.

# %% [markdown]
# #### 언어의 활용 사례
#
# 1. 자연어 처리
# 자연어 처리를 진행하면 글의 감정을 분석할 수 있다. 감정을 판단하기 위해서 긍정, 부정 문장을 모아 데이터를 만든후,
# 인공지능에게 각 문장의 긍정, 부정을 학습시킨다. 인공지능은 학습 과정에서 각 단어의 노출빈도를 바탕으로 데이터 외에 새로운 문자를 평가할 수 있다.
#
# 2. 심리상담 서비스
# 한 기업에서는 300자 내외의 고민 글을 작성하면 덱스트 속에 8가지 감정(좌절, 슬픔, 사랑 등)을 찾아낸다고 한다.
# 이를 찾기 위해 인공지능 기술뿐만 아니라 상담 심리학의 임상 경험과 데이터를 학습시킨다.
#
# 3. 악성 댓글 차단
# 한 게임사에서는 인공지능 기술로 악플을 관리하고 있다.
# 악플의 패턴을 학습한 인공지능은 변형시킨 아플에도 적응해 대응 할 수 있다.
#
# 4. 시나리오 작가
# 일본에서는 인공지능이 소설을 쓰기도 한다.
# 처음부터 인공지능이 집필하지 않는다. 먼저 사람이 큰 틀을 제시해주면 그 공백을 인공지능이 채우는 형식으로 진행된다.
# 예를 들어 '어떤 날씨에서', '무엇을 하고 있다.'라는 틀을 제시하면 인공지능이 '흐린 날씨', '소설을 쓰다'라는 구체적인 상황을 설정한다.
#
# [SAMSUNG SDS](https://www.samsungsds.com/global/ko/news/story/1203767_2919.html)

# %% [markdown]
# ### **음성인식**
# 스마트폰이 등장하고 여기에 음성인식 기술이 적용되기 시작하면서 대중화되기 시작하였다.
# 단순한 명령 정도만 알아듣는 음성 비서로 시작해서 더욱 다양한 분야에 적용되면서 빠르게 발전하고 있다.
# 음성인식을 전면에 내세운 **인공지능 스피커**가 등장했으며, 다양한 **스마트 가전 기기**에 음성인식 기능이 적용되고 있다.
# 더 나아가 **스마트 차량**도 곧 상용화 되어 출시 예정이다.

# %% [markdown]
# ### 일상에서 만나는 음성인식 기술
#
# 1. **TV**
# 자연어 음석인식 기능을 적용하여 말 한마디로 '인공지능 맞춤 검색'부터 '인공지능 TV 제어',
# '인공지능 영상.사운드 모드 조정'까지 가능하다.
#
# 2. **에어컨**
# 사용자의 언어를 스스로 학습하여 정해진 명령어뿐 아니라 "추워", "더워"와 같은 사용자의 자연스러운 반응에도 인식해 작동 여부를 먼저 제안한다.
# 또한 다양한 사투리를 사용하는 경우를 감안하여 각 지역마다 다른 억양 데이터도 확보하였다.
#
# 3. **세탁기**
# 음성만으로도 손쉽게 전원을 끄거나 세탁코스, 옵션을 설정할수 있게 되었다.
# 제품을 동작하는 데서 더 나아가 세탁기의 상태를 진단한 결과나 세탁방법을 음석으로 알려주기도 한다.
# 뿐만 아니라 고객의 제품 사용 패턴과 날씨 정보를 학습해 사용자에게 최적화된 세탁 옵션을 알아서 설정해주는 **스마트케어**기능을 탑재하였다.
#
# 4. **핸드폰**
# 음성인식 비서의 역할을 하고 있는 스마트폰, 내 주변뿐만이 아닌 멀리 떨어진 거리에서도 주변에 시끄러운 장소에서도 사용자의 목소리를 알아듣고 명령을
# 실행한다.
#
# 5. **의류관리기**
# 손으로 조작할 필요 없이 음성만으로 손쉽게 전원을 켜고 끄거나 의류관리 코스를 설정할 수 있다.
# 또한 제품의 동작 상태와 진단결과를 음성으로 알려주기도 한다.
#
# [네이버포스트](https://m.post.naver.com/viewer/postView.nhn?volumeNo=16706161&memberNo=39046504)

# %% [markdown]
# ### **자율주행**

# %% [markdown]
# 1. **개괄**
# 스마트폰 기반의 교통 서비스를 제공하는 우버의 예를 들자면 자사 서비스에 인공지능 개념을 적극적으로 활용해
# 차량이 필요한 수요자와 차량을 운행하는 공급자사이에 원활한 연결을 제공함으로써
# 정보 비대칭성을 줄이고 자원의 활용을 극대화하고 있다.
#
#    구글과 같은 회사는 플랫폼을 확장해나가는 관점에서 차량에 주목하고 있다.
# 차량은 사용자의 데이터를 축적하고 이를 활용하는 새로운 플랫폼으로 떠오르고 있고,
# 그 중에서도 가장 강력한 애플리케이션이 바로 자율주행 기능으로 본다.
# 자율주행차에 장착된 센서에서 수집된 각종 정보를 IoT를 지원하는 클라우드 컴퓨팅 환경으로 보내고,
# 빅데이터 기술을 사용해 운행 패턴과 도로상황을 분석한 다음에 해당 정보를 내려 받아 안전한 운전이 가능하게 만든다.
#
#    테슬라 같은 경우에는 소프트웨어 업그레이드만으로 제한적인 자율주행이 가능하게 만들었다.
# 또한 소프트웨어 업그레이드로 소환기능을 제공해 집에 도착해서 내리면 차량이 저절로 운전해서
# 차고로 들어간 다음에 시동이 꺼지고, 운행이 필요할 때 집 앞에 있으면 차량이 자동으로 시동을 걸고
# 차고 문을 열고 나와서 집앞으로 나올 수 있게 만들었다.
#
# 2. **자율주행 차량의 눈과 귀 : 센서**
# 다양한 센서에 의존해 경로를 결정하고 사고를 회피해야 한다. 쉽게 말해 센서는 자율주행차의
# 눈과 귀라고 생각할 수 있다. 자율주행차는 크게 다음과 같은 센서를 탑재한다.
#
# + **Radar**
# 레이더는 무선신호를 방출한 다음 부딪혀서 돌아오는 신호를 찾는 원리로 동작하는 가장 범용적으로
# 사용되는 센서로 단거리, 중거리, 장거리 특성을 모두 갖추고 날씨에 무관하게 동작한다.
#
# + **Lidar(Light Detection And Ranging)**
# 라이더는 지상의 형태와 표면 특성에 대한 지리적인 정보를 정밀하게 제공한다.
# 일반적으로 비행기, 지상, 이동 차량에서 넓은 지역에 걸쳐 빠르게 여러지점(point)을 수집하며,
# 높은 정밀도와 풍부한 지점 밀도라는 특성 때문에 철도, 도로, 교량, 빌딩, 방파제, 해안선에 대한
# 정교하고 현실적인 3차원 표현을 가능하게 한다.
# 라이더는 레이저를 발사해서 감지되는 반향을 센서가 잡아내는 원격 감지기술을 일컫는다.
# 목표 객체의 3차원 좌표(예: 위도, 경도, 고도)는 발사한 레이저 파동과 반환된 레이저 파동 사이의
# 시간, 파동이 발사된 각도, 센서의 절대 위치를 사용해 계산된다.
#
# + **Camera(일반/3D)**
# 특정 이미지를 개별 픽셀로 인식해 숫자로 변환하는 장비로 물체에서 반사되는 빛을 광학 센서가
# 잡는 원리로 동작한다.
# 일반 카메라는 깊이를 인식하지 못하는 반면에 3D카메라는 렌즈를 두 개 사용하거나 다른 센서의
# 도움을 받아 깊이를 인식할 수 있다.
#
# + **Ultrassonic**
# 음파(50 KHz 주변 초음파)를 보내 되돌아오는 반향을 듣는 장비로 음파가 미치는 주변 지역에
# 위치하는 물체를 감지할 수 있다.
#
# + **GPS(Global Positioning System)**
# GPS는 중궤도를 도는 24개 이상의 인공위성에서 발신하는 마이크로파를 수신기가 수신해 위치
# 벡터를 계산하는 방식으로 동작한다.
# GPS를 사용할 경우 현재 이동 중인 자율주행차의 정확한 위치를 구한 다음에, 미리 구축된 정밀한
# 도로 지도 데이터베이스를 토대로 정적인 주변 상황을 파악할 수 있다.
#
# + **적외선 LED와 광센서**
# 적외선 LED와 광센서는 비 탐지/와이퍼 동작과 같은 분야에 사용되며, 충돌회피를 위해 차량 외부에
# 장착돼 상향등의 조명 범위를 벗어난 물체를 감지하기 위해 사용되기도 한다.
#
# 3. **자율주행 차량의 두뇌 : CPU와 GPGPU**
# 차량의 센서에서 들어오는 각종 정보 역시 CPU와 GPGPU에서 처리하게 된다.
# CPU는 소프트웨어의 실행이 이뤄지는 핵심이며, 외부에서 정보를 입력받고, 기억하고,
# 컴퓨터 프로그램의 명령어를 해석하고 연산하고 외부로 출력한다.
# GPGPU는 SIMD 계산 유닛으로 여러 독립적인 데이터에 대한 병행연산을 수행할 능력을 갖추고 있다.
# 현대적인 GPGPU는 수천 개에 이르는 병행 스레드를 띄우고 모든 스레드를 배치 방식으로 처리한다.
# 이런 특성으로 인해, GPGPU는 복잡한 대규모 DSP 문제를 여러 개의 작은 수치 문제로 쪼개고
# 한 번에 처리한다.
# GPGPU를 사용하는 주요 분야를 정리하면
# 디지털 필터: 다차원 디지털 필터설계
# 레이더 시그널 재구성과 분석: 실시간으로 엄청나게 많은 3D나 4D 데이터 샘플 재구성
# 자율주행차 제어를 위한 3D이미지 인식
# 초음파, X레이, MRI, CT와 같은 2D 또는 3D 영상 시그널 진단 등 의료 영상 처리 등이다.
#
# [automotive](http://www.autoelectronics.co.kr/article/articleView.asp?idx=2114)
